# %% [markdown]
# ---
# # GEOMETRIC TRANSFORMATIONS
#
#
# ---

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#Storing the path of all Images in a list
imgpath = [ '..\Objects\lena_color_512.tif', '..\Objects\lbc.1.04.tiff',
            '..\Objects\l.1.01.tiff', '..\Objects\l.1.03.tiff' ]

# %% [markdown]
# ---
# ### SCALING
#
# ----
#
# In scaling resize function is passed parameters which changes the dimensionsof the image

# %%
#For loop to traverse each image of the list
for i in range(4):

    #Reading image from the list
    img = cv2.imread( imgpath[i] )

    #Calculating the dimensions of image
    width, height, channel = img.shape

    #Reszing the image to 1.3 times in x and 1.8 times in y its initial value
    resize = cv2.resize( img, None, fx = 1.3, fy = 1.8 )

    #Converting image to RGB for representing in matplotlib
    img = cv2.cvtColor( img, cv2.COLOR_BGR2RGB )
    resize = cv2.cvtColor( resize, cv2.COLOR_BGR2RGB )

    #plotting orignal image and rotated image for comparison
    #plt.subplot(4,2,2*i+1)
    plt.title('Orignal')
    plt.imshow( img )
    plt.xticks([])
    plt.yticks([])
    plt.show()
    #plt.subplot(4,2,2*i+2)
    plt.imshow( resize )
    plt.title('Scaled')
    plt.xticks([])
    plt.yticks([])
    plt.show()


#showing image which is plotted
#plt.show()

# %% [markdown]
# ---
# ### TRANSLATION
#
# ---
#
# * In translation, a matrix is created such that the value of first two elements decides the direction and third decides the distance to move the image
#
# * warpAffine function changes the positon of image on the basis on tranlation matrix and it can also change the dimesion of the output image

# %%
#For loop to traverse each image of the list
for i in range(4):

    #Reading image from the list
    img = cv2.imread( imgpath[i] )

    #Calculating the dimensions of image
    width, height, channel = img.shape


    #It will create a matrix which is used to translate the image
    T = np.float32( [ [ 1, 0, 50 ], [ 0, 1 , 50 ] ] )

    #This will translate the image with amount given by the matrix
    trans=cv2.warpAffine( img , T, ( width + 50 , height + 50 ) )


    #Converting image to RGB for representing in matplotlib
    img = cv2.cvtColor( img, cv2.COLOR_BGR2RGB )
    trans = cv2.cvtColor( trans, cv2.COLOR_BGR2RGB )


    #plotting origanl image and rotated image for comparison
    #plt.subplot(4,2,2*i+1)
    plt.title('Orignal')
    plt.imshow( img )
    plt.xticks([])
    plt.yticks([])
    plt.show()
    #plt.subplot(4,2,2*i+2)
    plt.imshow( trans )
    plt.title('Translated')
    plt.xticks([])
    plt.yticks([])
    plt.show()

#showing image which is plotted
#plt.show()

# %% [markdown]
# ---
# ### ROTATION
#
# ---
#
# * The rotationMatrix2D function creates a matrix in such a way that the Affine transform of the function with the given matrix rotates the image

# %%
#For loop to traverse each image of the list
for i in range(4):

    #Reading image from the list
    img = cv2.imread( imgpath[i] )

    #Calculating the dimensions of image
    width, height, channel = img.shape

    #Generating Matrix for warp affine
    R = cv2.getRotationMatrix2D( ( width / 2, height / 2 ), 90, 1 )

    #Generating rotated image
    rotate = cv2.warpAffine( img, R, ( width, height ) )


    #Converting image to RGB for representing in matplotlib
    img = cv2.cvtColor( img, cv2.COLOR_BGR2RGB )
    rotate = cv2.cvtColor( rotate, cv2.COLOR_BGR2RGB )


    #plotting origanl image and rotated image for comparison
    #plt.subplot(4,2,2*i+1)
    plt.title('Orignal')
    plt.imshow( img )
    plt.xticks([])
    plt.yticks([])
    plt.show()
    #plt.subplot(4,2,2*i+2)
    plt.imshow( rotate )
    plt.title('Rotated')
    plt.xticks([])
    plt.yticks([])
    plt.show()
    

#showing image which is plotted
#plt.show()

# %% [markdown]
# ---
# ### PERSPECTIVE TRANSFORM
#
# ---
#
# * Perspective transform takes four points of input image and four point of output image and from this data it generates a mapping from tihr input image to the output image
#
# * Then this matrix mapping is passed to the warpPerspective function to generate the output image

# %%
#For loop to traverse each image of the list
for i in range(4):

    #Reading image from the list
    img = cv2.imread( imgpath[i] )

    #Calculating the dimensions of image
    width, height, channel = img.shape

    #points on input and outut image
    pointI = np.float32( [ [ 0, 0 ], [ 300, 0 ], [ 150, 300 ], [ 300, 300 ] ] )
    pointO = np.float32( [ [ 0, 0 ], [ 350, 0 ], [ 0, 350 ], [ 350, 350 ] ] )

    #It is used to create matrix for image to output mapping
    P=cv2.getPerspectiveTransform( pointI, pointO )

    #This will transform the image to given perspective
    pers=cv2.warpPerspective(img, P, ( width, height) )

    #Converting image to RGB for representing in matplotlib
    img = cv2.cvtColor( img, cv2.COLOR_BGR2RGB )
    pers = cv2.cvtColor( pers, cv2.COLOR_BGR2RGB )

    #plotting orignal image and rotated image for comparison
    #plt.subplot(4,2,2*i+1)
    plt.title('Orignal')
    plt.imshow( img )
    plt.xticks([])
    plt.yticks([])
    plt.show()
    #plt.subplot(4,2,2*i+2)
    plt.imshow( pers )
    plt.title('Output')
    plt.xticks([])
    plt.yticks([])
    plt.show()
    

#showing image which is plotted
#plt.show()
